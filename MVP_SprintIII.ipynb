# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoodon/mvp_sprintIII/blob/main/MVP_SprintIII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
import pandas as pd

url_alerts = 'https://raw.githubusercontent.com/brunoodon/mvp-sprint1/main/vulnerability_alerts.csv'
df_alerts = pd.read_csv(url_alerts)
display(df_alerts)
# Out:
#       Vulnerability  SeverityScore  \
# 0    CVE-2022-41082            8.8
# 1    CVE-2022-41082            8.8
# 2    CVE-2022-41040            8.8
# 3    CVE-2021-34523            9.8
# 4    CVE-2021-34473            9.8
# ..              ...            ...
# 807   CVE-2015-6175            7.2
# 808   CVE-2015-2426            9.3
# 809   CVE-2015-1769            7.2
# 810  CVE-2022-41082            8.8
# 811  CVE-2022-41082            8.8
#
#                                      VulnerabilityName   AlertDate  \
# 0    Microsoft Exchange Server Remote Code Executio...  2023-04-28
# 1    Microsoft Exchange Server Remote Code Executio...  2023-04-28
# 2    Microsoft Exchange Server Server-Side Request ...  2023-04-28
# 3    Microsoft Exchange Server Privilege Escalation...  2023-04-28
# 4    Microsoft Exchange Server Remote Code Executio...  2023-04-28
# ..                                                 ...         ...
# 807  Microsoft Windows Kernel Privilege Escalation ...  2023-04-24
# 808  Microsoft Windows Adobe Type Manager Library R...  2023-04-24
# 809  Microsoft Windows Mount Manager Privilege Esca...  2023-04-24
# 810  Microsoft Exchange Server Remote Code Executio...  2023-04-28
# 811  Microsoft Exchange Server Remote Code Executio...  2023-04-28
#
#          Application Department  \
# 0    Exchange Server         TI
# 1    Exchange Server         TI
# 2    Exchange Server         TI
# 3    Exchange Server         TI
# 4    Exchange Server         TI
# ..               ...        ...
# 807          Windows         RH
# 808          Windows         RH
# 809          Windows         RH
# 810  Exchange Server         TI
# 811  Exchange Server         TI
#
#                                            Description  \
# 0    Microsoft Exchange Server contains an unspecif...
# 1    Microsoft Exchange Server contains an unspecif...
# 2    Microsoft Exchange Server allows for server-si...
# 3    Microsoft Exchange Server Privilege Escalation...
# 4    Microsoft Exchange Server Remote Code Executio...
# ..                                                 ...
# 807  The kernel in Microsoft Windows contains a vul...
# 808  A remote code execution vulnerability exists i...
# 809  A privilege escalation vulnerability exists wh...
# 810  Microsoft Exchange Server contains an unspecif...
# 811  Microsoft Exchange Server contains an unspecif...
#
#                                ExploitationVector           Hostname  \
# 0    CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# 1    CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# 2    CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# 3    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# 4    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# ..                                            ...                ...
# 807                    AV:L/AC:L/Au:N/C:C/I:C/A:C               dp04
# 808                    AV:N/AC:M/Au:N/C:C/I:C/A:C               dp04
# 809                    AV:L/AC:L/Au:N/C:C/I:C/A:C               dp04
# 810  CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
# 811  CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  mail.fakecomp.com
#
#                IP     Vendor
# 0     172.16.0.20  Microsoft
# 1     172.16.0.20  Microsoft
# 2     172.16.0.20  Microsoft
# 3     172.16.0.20  Microsoft
# 4     172.16.0.20  Microsoft
# ..            ...        ...
# 807  192.168.7.34  Microsoft
# 808  192.168.7.34  Microsoft
# 809  192.168.7.34  Microsoft
# 810   172.16.0.20  Microsoft
# 811   172.16.0.20  Microsoft
#
# [812 rows x 11 columns]
