# %%
# %fs ls dbfs:/cve-alerts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/cve-alerts/vulnerability_alerts.csv</td><td>vulnerability_alerts.csv</td><td>269810</td><td>1694826784000</td></tr></tbody></table></div>

# %%
import requests
import csv
import pandas as pd
import shutil
url_alerts = 'https://raw.githubusercontent.com/brunoodon/mvp-sprint1/main/vulnerability_alerts.csv'
df_alerts = pd.read_csv(url_alerts)
display(df_alerts)
df_alerts.to_csv("/dbfs/cve-alerts/vulnerability_alerts.csv")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/cve-alerts/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/cve-alerts/vulnerability_alerts.csv</td><td>vulnerability_alerts.csv</td><td>269810</td><td>1694826893000</td></tr></tbody></table></div>
